# %% [markdown]
# # Deliverable 1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import json

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
#Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
    
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]


        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": str(weather_desc)})

        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | luderitz
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | fillmore
# Processing Record 5 of Set 1 | avarua
# Processing Record 6 of Set 1 | saskylakh
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | nikolskoye
# Processing Record 9 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 1 | leh
# Processing Record 11 of Set 1 | saint-pierre
# Processing Record 12 of Set 1 | nanortalik
# Processing Record 13 of Set 1 | sisimiut
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | maumere
# Processing Record 16 of Set 1 | manacapuru
# Processing Record 17 of Set 1 | maralal
# Processing Record 18 of Set 1 | robat karim
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | eyl
# Processing Record 21 of Set 1 | punta arenas
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | butaritari
# Processing Record 25 of Set 1 | gouyave
# Processing Record 26 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 27 of Set 1 | pisco
# Processing Record 28 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | taoudenni
# Processing Record 32 of Set 1 | yellowknife
# Processing Record 33 of Set 1 | tinskoy
# Processing Record 34 of Set 1 | khonsa
# Processing Record 35 of Set 1 | yarke pole
# Processing Record 36 of Set 1 | nouadhibou
# Processing Record 37 of Set 1 | pochutla
# Processing Record 38 of Set 1 | chak azam sahu
# Processing Record 39 of Set 1 | berlevag
# Processing Record 40 of Set 1 | grand forks
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | bethel
# Processing Record 43 of Set 1 | jalpan
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | norman wells
# Processing Record 47 of Set 1 | tessalit
# Processing Record 48 of Set 1 | minab
# Processing Record 49 of Set 1 | chegutu
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | souillac
# Processing Record 2 of Set 2 | temple
# Processing Record 3 of Set 2 | jamestown
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | port-cartier
# Processing Record 6 of Set 2 | sabla
# Processing Record 7 of Set 2 | hobart
# Processing Record 8 of Set 2 | singaraja
# Processing Record 9 of Set 2 | qaqortoq
# Processing Record 10 of Set 2 | urucara
# Processing Record 11 of Set 2 | kolokani
# Processing Record 12 of Set 2 | ilhabela
# Processing Record 13 of Set 2 | gorin
# Processing Record 14 of Set 2 | fertod
# Processing Record 15 of Set 2 | yuxia
# Processing Record 16 of Set 2 | tura
# Processing Record 17 of Set 2 | amuntai
# Processing Record 18 of Set 2 | sahrak
# City not found. Skipping...
# Processing Record 19 of Set 2 | murashi
# Processing Record 20 of Set 2 | itoman
# Processing Record 21 of Set 2 | kalmunai
# Processing Record 22 of Set 2 | mahebourg
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | talnakh
# Processing Record 25 of Set 2 | cape town
# Processing Record 26 of Set 2 | arraial do cabo
# Processing Record 27 of Set 2 | port elizabeth
# Processing Record 28 of Set 2 | kaitangata
# Processing Record 29 of Set 2 | vysokogornyy
# Processing Record 30 of Set 2 | zhemtala
# Processing Record 31 of Set 2 | castro
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | krasnyy chikoy
# Processing Record 34 of Set 2 | cabo san lucas
# Processing Record 35 of Set 2 | zhigansk
# Processing Record 36 of Set 2 | magnolia
# Processing Record 37 of Set 2 | hamilton
# Processing Record 38 of Set 2 | coquimbo
# Processing Record 39 of Set 2 | puerto ayora
# Processing Record 40 of Set 2 | nouakchott
# Processing Record 41 of Set 2 | micheweni
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | upernavik
# Processing Record 44 of Set 2 | ahuimanu
# Processing Record 45 of Set 2 | esperance
# Processing Record 46 of Set 2 | biltine
# Processing Record 47 of Set 2 | januaria
# Processing Record 48 of Set 2 | kodiak
# Processing Record 49 of Set 2 | hermanus
# Processing Record 50 of Set 2 | ena
# Processing Record 1 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 3 | broome
# Processing Record 3 of Set 3 | havoysund
# Processing Record 4 of Set 3 | novaya zaimka
# Processing Record 5 of Set 3 | saint-joseph
# Processing Record 6 of Set 3 | narsaq
# Processing Record 7 of Set 3 | katsuura
# Processing Record 8 of Set 3 | kusk
# City not found. Skipping...
# Processing Record 9 of Set 3 | nizhniy odes
# Processing Record 10 of Set 3 | evensk
# Processing Record 11 of Set 3 | kisangani
# Processing Record 12 of Set 3 | thompson
# Processing Record 13 of Set 3 | barrow
# Processing Record 14 of Set 3 | orocue
# Processing Record 15 of Set 3 | khasan
# Processing Record 16 of Set 3 | abha
# Processing Record 17 of Set 3 | hithadhoo
# Processing Record 18 of Set 3 | qaanaaq
# Processing Record 19 of Set 3 | grand baie
# Processing Record 20 of Set 3 | dingle
# Processing Record 21 of Set 3 | keuruu
# Processing Record 22 of Set 3 | ishigaki
# Processing Record 23 of Set 3 | saint-philippe
# Processing Record 24 of Set 3 | dubti
# Processing Record 25 of Set 3 | kruisfontein
# Processing Record 26 of Set 3 | klaksvik
# Processing Record 27 of Set 3 | torbay
# Processing Record 28 of Set 3 | strezhevoy
# Processing Record 29 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 3 | husavik
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | namatanai
# Processing Record 33 of Set 3 | bambous virieux
# Processing Record 34 of Set 3 | avera
# Processing Record 35 of Set 3 | vaini
# Processing Record 36 of Set 3 | andijon
# Processing Record 37 of Set 3 | san vicente
# Processing Record 38 of Set 3 | lorengau
# Processing Record 39 of Set 3 | komsomolskiy
# Processing Record 40 of Set 3 | north battleford
# Processing Record 41 of Set 3 | kavaratti
# Processing Record 42 of Set 3 | tasiilaq
# Processing Record 43 of Set 3 | yumen
# Processing Record 44 of Set 3 | tecoanapa
# Processing Record 45 of Set 3 | coihaique
# Processing Record 46 of Set 3 | nampula
# Processing Record 47 of Set 3 | faya
# Processing Record 48 of Set 3 | kibondo
# Processing Record 49 of Set 3 | leningradskiy
# Processing Record 50 of Set 3 | bandarbeyla
# Processing Record 1 of Set 4 | finnsnes
# Processing Record 2 of Set 4 | vuktyl
# Processing Record 3 of Set 4 | beidao
# Processing Record 4 of Set 4 | wewak
# Processing Record 5 of Set 4 | tuatapere
# Processing Record 6 of Set 4 | cap malheureux
# Processing Record 7 of Set 4 | surt
# Processing Record 8 of Set 4 | ereymentau
# Processing Record 9 of Set 4 | hambantota
# Processing Record 10 of Set 4 | kamenka
# Processing Record 11 of Set 4 | skjervoy
# Processing Record 12 of Set 4 | saldanha
# Processing Record 13 of Set 4 | luis correia
# Processing Record 14 of Set 4 | zaraza
# Processing Record 15 of Set 4 | santander
# Processing Record 16 of Set 4 | tawau
# Processing Record 17 of Set 4 | valdivia
# Processing Record 18 of Set 4 | oranjemund
# Processing Record 19 of Set 4 | mogochin
# City not found. Skipping...
# Processing Record 20 of Set 4 | kaputa
# Processing Record 21 of Set 4 | hilo
# Processing Record 22 of Set 4 | belmonte
# Processing Record 23 of Set 4 | saint george
# Processing Record 24 of Set 4 | mount gambier
# Processing Record 25 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 4 | ponta do sol
# Processing Record 27 of Set 4 | moron
# Processing Record 28 of Set 4 | rio gallegos
# Processing Record 29 of Set 4 | dikson
# Processing Record 30 of Set 4 | progreso
# Processing Record 31 of Set 4 | tarabuco
# Processing Record 32 of Set 4 | faanui
# Processing Record 33 of Set 4 | kollumerland
# City not found. Skipping...
# Processing Record 34 of Set 4 | cayenne
# Processing Record 35 of Set 4 | sobolevo
# Processing Record 36 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 4 | lazaro cardenas
# Processing Record 38 of Set 4 | kyshtovka
# Processing Record 39 of Set 4 | fortuna
# Processing Record 40 of Set 4 | lamu
# Processing Record 41 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 42 of Set 4 | laguna
# Processing Record 43 of Set 4 | aklavik
# Processing Record 44 of Set 4 | mogadishu
# Processing Record 45 of Set 4 | honiara
# Processing Record 46 of Set 4 | seoul
# Processing Record 47 of Set 4 | vila franca do campo
# Processing Record 48 of Set 4 | sura mare
# Processing Record 49 of Set 4 | geraldton
# Processing Record 50 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 5 | diego de almagro
# Processing Record 2 of Set 5 | flinders
# Processing Record 3 of Set 5 | bonfim
# Processing Record 4 of Set 5 | mitsamiouli
# Processing Record 5 of Set 5 | bredasdorp
# Processing Record 6 of Set 5 | santiago del estero
# Processing Record 7 of Set 5 | severo-kurilsk
# Processing Record 8 of Set 5 | haines junction
# Processing Record 9 of Set 5 | lebu
# Processing Record 10 of Set 5 | savonlinna
# Processing Record 11 of Set 5 | sakaiminato
# Processing Record 12 of Set 5 | steamboat springs
# Processing Record 13 of Set 5 | nome
# Processing Record 14 of Set 5 | pacific grove
# Processing Record 15 of Set 5 | sitka
# Processing Record 16 of Set 5 | vardo
# Processing Record 17 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 18 of Set 5 | marawi
# Processing Record 19 of Set 5 | nshamba
# Processing Record 20 of Set 5 | marovoay
# Processing Record 21 of Set 5 | yar-sale
# Processing Record 22 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 5 | oranjestad
# Processing Record 24 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 5 | koszeg
# Processing Record 26 of Set 5 | jasper
# Processing Record 27 of Set 5 | chokurdakh
# Processing Record 28 of Set 5 | durango
# Processing Record 29 of Set 5 | pevek
# Processing Record 30 of Set 5 | copiapo
# Processing Record 31 of Set 5 | santiago
# Processing Record 32 of Set 5 | nizwa
# Processing Record 33 of Set 5 | san patricio
# Processing Record 34 of Set 5 | namibe
# Processing Record 35 of Set 5 | sangar
# Processing Record 36 of Set 5 | karratha
# Processing Record 37 of Set 5 | zaokskiy
# Processing Record 38 of Set 5 | alekseyevsk
# Processing Record 39 of Set 5 | xingyi
# Processing Record 40 of Set 5 | necochea
# Processing Record 41 of Set 5 | palmerston
# Processing Record 42 of Set 5 | aykhal
# Processing Record 43 of Set 5 | chipinge
# Processing Record 44 of Set 5 | colon
# Processing Record 45 of Set 5 | inyonga
# Processing Record 46 of Set 5 | novyy urgal
# Processing Record 47 of Set 5 | bakchar
# Processing Record 48 of Set 5 | port keats
# Processing Record 49 of Set 5 | marsa matruh
# Processing Record 50 of Set 5 | machachi
# Processing Record 1 of Set 6 | kahului
# Processing Record 2 of Set 6 | chester
# Processing Record 3 of Set 6 | labuhan
# Processing Record 4 of Set 6 | easthampton
# Processing Record 5 of Set 6 | ulu-telyak
# Processing Record 6 of Set 6 | rio grande
# Processing Record 7 of Set 6 | brae
# Processing Record 8 of Set 6 | bafoulabe
# Processing Record 9 of Set 6 | longyearbyen
# Processing Record 10 of Set 6 | itarema
# Processing Record 11 of Set 6 | burnie
# Processing Record 12 of Set 6 | nipawin
# Processing Record 13 of Set 6 | nishihara
# Processing Record 14 of Set 6 | grande prairie
# Processing Record 15 of Set 6 | caramay
# Processing Record 16 of Set 6 | syedove
# Processing Record 17 of Set 6 | touros
# Processing Record 18 of Set 6 | kjopsvik
# Processing Record 19 of Set 6 | garowe
# Processing Record 20 of Set 6 | chuy
# Processing Record 21 of Set 6 | gat
# Processing Record 22 of Set 6 | clyde river
# Processing Record 23 of Set 6 | sokoni
# Processing Record 24 of Set 6 | san cristobal
# Processing Record 25 of Set 6 | tselinnoye
# Processing Record 26 of Set 6 | itaobim
# Processing Record 27 of Set 6 | victoria
# Processing Record 28 of Set 6 | atuona
# Processing Record 29 of Set 6 | aasiaat
# Processing Record 30 of Set 6 | hokitika
# Processing Record 31 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 6 | bathsheba
# Processing Record 33 of Set 6 | kutum
# Processing Record 34 of Set 6 | areia branca
# Processing Record 35 of Set 6 | totness
# Processing Record 36 of Set 6 | ambon
# Processing Record 37 of Set 6 | kodinsk
# Processing Record 38 of Set 6 | ust-kut
# Processing Record 39 of Set 6 | wilmington
# Processing Record 40 of Set 6 | saint-paul
# Processing Record 41 of Set 6 | codrington
# Processing Record 42 of Set 6 | ulcinj
# Processing Record 43 of Set 6 | saint-francois
# Processing Record 44 of Set 6 | kununurra
# Processing Record 45 of Set 6 | vanavara
# Processing Record 46 of Set 6 | taveta
# Processing Record 47 of Set 6 | donskoye
# Processing Record 48 of Set 6 | nago
# Processing Record 49 of Set 6 | rawson
# Processing Record 50 of Set 6 | high level
# Processing Record 1 of Set 7 | chapais
# Processing Record 2 of Set 7 | araouane
# Processing Record 3 of Set 7 | catamarca
# Processing Record 4 of Set 7 | mmabatho
# Processing Record 5 of Set 7 | lamar
# Processing Record 6 of Set 7 | pauini
# Processing Record 7 of Set 7 | alice springs
# Processing Record 8 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 7 | college
# Processing Record 10 of Set 7 | olafsvik
# Processing Record 11 of Set 7 | isangel
# Processing Record 12 of Set 7 | buraydah
# Processing Record 13 of Set 7 | hurghada
# Processing Record 14 of Set 7 | ilulissat
# Processing Record 15 of Set 7 | poronaysk
# Processing Record 16 of Set 7 | lasa
# Processing Record 17 of Set 7 | dalvik
# Processing Record 18 of Set 7 | waipawa
# Processing Record 19 of Set 7 | antofagasta
# Processing Record 20 of Set 7 | airai
# Processing Record 21 of Set 7 | stephenville
# Processing Record 22 of Set 7 | iqaluit
# Processing Record 23 of Set 7 | turlock
# Processing Record 24 of Set 7 | agadir
# Processing Record 25 of Set 7 | beringovskiy
# Processing Record 26 of Set 7 | lata
# Processing Record 27 of Set 7 | yerofey pavlovich
# Processing Record 28 of Set 7 | mount isa
# Processing Record 29 of Set 7 | leshukonskoye
# Processing Record 30 of Set 7 | dandong
# Processing Record 31 of Set 7 | bengkulu
# Processing Record 32 of Set 7 | khowst
# Processing Record 33 of Set 7 | rehoboth
# Processing Record 34 of Set 7 | olovyannaya
# Processing Record 35 of Set 7 | jiwani
# Processing Record 36 of Set 7 | comonfort
# Processing Record 37 of Set 7 | ayios matthaios
# City not found. Skipping...
# Processing Record 38 of Set 7 | bilma
# Processing Record 39 of Set 7 | launceston
# Processing Record 40 of Set 7 | sakakah
# Processing Record 41 of Set 7 | yarmouth
# Processing Record 42 of Set 7 | baoqing
# Processing Record 43 of Set 7 | zeya
# Processing Record 44 of Set 7 | joao camara
# Processing Record 45 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 7 | dudinka
# Processing Record 47 of Set 7 | charters towers
# Processing Record 48 of Set 7 | sao jose da coroa grande
# Processing Record 49 of Set 7 | kribi
# Processing Record 50 of Set 7 | cherskiy
# Processing Record 1 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 8 | padang
# Processing Record 3 of Set 8 | axim
# Processing Record 4 of Set 8 | byron bay
# Processing Record 5 of Set 8 | ust-tsilma
# Processing Record 6 of Set 8 | bethanien
# Processing Record 7 of Set 8 | zalari
# Processing Record 8 of Set 8 | panguna
# Processing Record 9 of Set 8 | sorland
# Processing Record 10 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 11 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 12 of Set 8 | jiuquan
# Processing Record 13 of Set 8 | becerril
# Processing Record 14 of Set 8 | ust-uda
# Processing Record 15 of Set 8 | saint-augustin
# Processing Record 16 of Set 8 | iskateley
# Processing Record 17 of Set 8 | awbari
# Processing Record 18 of Set 8 | amapa
# Processing Record 19 of Set 8 | chulumani
# Processing Record 20 of Set 8 | bolshiye klyuchishchi
# City not found. Skipping...
# Processing Record 21 of Set 8 | ouadda
# Processing Record 22 of Set 8 | san jose
# Processing Record 23 of Set 8 | lashio
# Processing Record 24 of Set 8 | kirillov
# Processing Record 25 of Set 8 | polyarnyy
# Processing Record 26 of Set 8 | roald
# Processing Record 27 of Set 8 | kuching
# Processing Record 28 of Set 8 | klyuchi
# Processing Record 29 of Set 8 | mayo
# Processing Record 30 of Set 8 | te anau
# Processing Record 31 of Set 8 | olopa
# Processing Record 32 of Set 8 | fort nelson
# Processing Record 33 of Set 8 | los llanos de aridane
# Processing Record 34 of Set 8 | inzer
# Processing Record 35 of Set 8 | sola
# Processing Record 36 of Set 8 | turukhansk
# Processing Record 37 of Set 8 | kabrai
# Processing Record 38 of Set 8 | grindavik
# Processing Record 39 of Set 8 | tsaratanana
# Processing Record 40 of Set 8 | sistranda
# Processing Record 41 of Set 8 | sandwick
# Processing Record 42 of Set 8 | auki
# Processing Record 43 of Set 8 | walvis bay
# Processing Record 44 of Set 8 | lompoc
# Processing Record 45 of Set 8 | jingdezhen
# Processing Record 46 of Set 8 | grand gaube
# Processing Record 47 of Set 8 | trinidad
# Processing Record 48 of Set 8 | martapura
# Processing Record 49 of Set 8 | madarjac
# City not found. Skipping...
# Processing Record 50 of Set 8 | karachi
# Processing Record 1 of Set 9 | columbus
# Processing Record 2 of Set 9 | adrar
# Processing Record 3 of Set 9 | fergus falls
# Processing Record 4 of Set 9 | mocajuba
# Processing Record 5 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 6 of Set 9 | kavieng
# Processing Record 7 of Set 9 | kamaishi
# Processing Record 8 of Set 9 | ruteng
# Processing Record 9 of Set 9 | calama
# Processing Record 10 of Set 9 | veraval
# Processing Record 11 of Set 9 | hasaki
# Processing Record 12 of Set 9 | tautira
# Processing Record 13 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 9 | nelson bay
# Processing Record 15 of Set 9 | neuquen
# Processing Record 16 of Set 9 | escondido
# Processing Record 17 of Set 9 | belaya gora
# Processing Record 18 of Set 9 | lensk
# Processing Record 19 of Set 9 | quelimane
# Processing Record 20 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 9 | nayoro
# Processing Record 22 of Set 9 | dunedin
# Processing Record 23 of Set 9 | montepuez
# Processing Record 24 of Set 9 | dongsheng
# Processing Record 25 of Set 9 | svolvaer
# Processing Record 26 of Set 9 | acapulco
# Processing Record 27 of Set 9 | mersing
# Processing Record 28 of Set 9 | buala
# Processing Record 29 of Set 9 | paamiut
# Processing Record 30 of Set 9 | maceio
# Processing Record 31 of Set 9 | dongobesh
# Processing Record 32 of Set 9 | kargasok
# Processing Record 33 of Set 9 | togur
# Processing Record 34 of Set 9 | tual
# Processing Record 35 of Set 9 | hangu
# Processing Record 36 of Set 9 | gold coast
# Processing Record 37 of Set 9 | nantucket
# Processing Record 38 of Set 9 | grafton
# Processing Record 39 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 40 of Set 9 | mayna
# Processing Record 41 of Set 9 | ribeira grande
# Processing Record 42 of Set 9 | strelka
# Processing Record 43 of Set 9 | chinsali
# Processing Record 44 of Set 9 | demak
# Processing Record 45 of Set 9 | westport
# Processing Record 46 of Set 9 | sechura
# Processing Record 47 of Set 9 | constitucion
# Processing Record 48 of Set 9 | takoradi
# Processing Record 49 of Set 9 | yemelyanovo
# Processing Record 50 of Set 9 | xadani
# City not found. Skipping...
# Processing Record 1 of Set 10 | colesberg
# Processing Record 2 of Set 10 | atar
# Processing Record 3 of Set 10 | baherden
# Processing Record 4 of Set 10 | santa lucia
# Processing Record 5 of Set 10 | batavia
# Processing Record 6 of Set 10 | caravelas
# Processing Record 7 of Set 10 | inuvik
# Processing Record 8 of Set 10 | san luis
# Processing Record 9 of Set 10 | wagar
# Processing Record 10 of Set 10 | akyab
# Processing Record 11 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 10 | melykut
# Processing Record 13 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 14 of Set 10 | tonj
# Processing Record 15 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 10 | saint anthony
# Processing Record 17 of Set 10 | baturaja
# Processing Record 18 of Set 10 | vostok
# Processing Record 19 of Set 10 | kitui
# Processing Record 20 of Set 10 | ixtapa
# Processing Record 21 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 22 of Set 10 | port shepstone
# Processing Record 23 of Set 10 | half moon bay
# Processing Record 24 of Set 10 | abrau-dyurso
# Processing Record 25 of Set 10 | doha
# Processing Record 26 of Set 10 | palmas bellas
# Processing Record 27 of Set 10 | beloha
# Processing Record 28 of Set 10 | ancud
# Processing Record 29 of Set 10 | beaverlodge
# Processing Record 30 of Set 10 | korla
# Processing Record 31 of Set 10 | whitecourt
# Processing Record 32 of Set 10 | wajima
# Processing Record 33 of Set 10 | degtyarsk
# Processing Record 34 of Set 10 | bouna
# Processing Record 35 of Set 10 | chama
# Processing Record 36 of Set 10 | coahuayana
# Processing Record 37 of Set 10 | muroto
# Processing Record 38 of Set 10 | sabang
# Processing Record 39 of Set 10 | domoni
# Processing Record 40 of Set 10 | mayumba
# Processing Record 41 of Set 10 | hohhot
# Processing Record 42 of Set 10 | wajir
# Processing Record 43 of Set 10 | pangnirtung
# Processing Record 44 of Set 10 | parana
# Processing Record 45 of Set 10 | harper
# Processing Record 46 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 10 | sundsvall
# Processing Record 48 of Set 10 | sao filipe
# Processing Record 49 of Set 10 | burgersdorp
# Processing Record 50 of Set 10 | wentzville
# Processing Record 1 of Set 11 | galveston
# Processing Record 2 of Set 11 | normandin
# Processing Record 3 of Set 11 | fare
# Processing Record 4 of Set 11 | farafangana
# Processing Record 5 of Set 11 | colares
# Processing Record 6 of Set 11 | bokoro
# Processing Record 7 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 8 of Set 11 | griffith
# Processing Record 9 of Set 11 | nokaneng
# Processing Record 10 of Set 11 | betare oya
# Processing Record 11 of Set 11 | portland
# Processing Record 12 of Set 11 | sumbe
# Processing Record 13 of Set 11 | canatlan
# Processing Record 14 of Set 11 | guerrero negro
# Processing Record 15 of Set 11 | flin flon
# Processing Record 16 of Set 11 | wylie
# Processing Record 17 of Set 11 | lokoja
# Processing Record 18 of Set 11 | port lincoln
# Processing Record 19 of Set 11 | bilibino
# Processing Record 20 of Set 11 | kawalu
# Processing Record 21 of Set 11 | galiwinku
# City not found. Skipping...
# Processing Record 22 of Set 11 | mehamn
# Processing Record 23 of Set 11 | gamba
# Processing Record 24 of Set 11 | shirwal
# Processing Record 25 of Set 11 | aquiraz
# Processing Record 26 of Set 11 | purpe
# Processing Record 27 of Set 11 | kifri
# Processing Record 28 of Set 11 | sokolovo
# Processing Record 29 of Set 11 | djambala
# Processing Record 30 of Set 11 | port macquarie
# Processing Record 31 of Set 11 | taltal
# Processing Record 32 of Set 11 | baijiantan
# Processing Record 33 of Set 11 | turan
# Processing Record 34 of Set 11 | comodoro rivadavia
# Processing Record 35 of Set 11 | ketchikan
# Processing Record 36 of Set 11 | bo phloi
# Processing Record 37 of Set 11 | salalah
# Processing Record 38 of Set 11 | handwara
# City not found. Skipping...
# Processing Record 39 of Set 11 | el wasta
# City not found. Skipping...
# Processing Record 40 of Set 11 | alyangula
# Processing Record 41 of Set 11 | srandakan
# Processing Record 42 of Set 11 | port moresby
# Processing Record 43 of Set 11 | margate
# Processing Record 44 of Set 11 | ushtobe
# Processing Record 45 of Set 11 | guiyang
# Processing Record 46 of Set 11 | karbinci
# Processing Record 47 of Set 11 | smithers
# Processing Record 48 of Set 11 | waingapu
# Processing Record 49 of Set 11 | sembabule
# Processing Record 50 of Set 11 | la gaulette
# City not found. Skipping...
# Processing Record 1 of Set 12 | a
# City not found. Skipping...
# Processing Record 2 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 3 of Set 12 | gardiner
# Processing Record 4 of Set 12 | suluq
# Processing Record 5 of Set 12 | deming
# Processing Record 6 of Set 12 | inhambane
# Processing Record 7 of Set 12 | tabou
# Processing Record 8 of Set 12 | natal
# Processing Record 9 of Set 12 | komatipoort
# Processing Record 10 of Set 12 | rocha
# Processing Record 11 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 12 | camacha
# Processing Record 13 of Set 12 | turayf
# Processing Record 14 of Set 12 | scarborough
# Processing Record 15 of Set 12 | whitehorse
# Processing Record 16 of Set 12 | togitsu
# Processing Record 17 of Set 12 | yulara
# Processing Record 18 of Set 12 | marshalltown
# Processing Record 19 of Set 12 | tiksi
# Processing Record 20 of Set 12 | vila velha
# Processing Record 21 of Set 12 | lavrentiya
# Processing Record 22 of Set 12 | antipino
# Processing Record 23 of Set 12 | vanimo
# Processing Record 24 of Set 12 | cidreira
# Processing Record 25 of Set 12 | qeshm
# Processing Record 26 of Set 12 | sioux lookout
# Processing Record 27 of Set 12 | vernon
# Processing Record 28 of Set 12 | senmonorom
# City not found. Skipping...
# Processing Record 29 of Set 12 | kaeo
# Processing Record 30 of Set 12 | virginia beach
# Processing Record 31 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 32 of Set 12 | kulhudhuffushi
# Processing Record 33 of Set 12 | puerto narino
# Processing Record 34 of Set 12 | khorinsk
# Processing Record 35 of Set 12 | thunder bay
# Processing Record 36 of Set 12 | lakatoro
# Processing Record 37 of Set 12 | aden
# Processing Record 38 of Set 12 | alofi
# Processing Record 39 of Set 12 | okhotsk
# Processing Record 40 of Set 12 | san blas
# Processing Record 41 of Set 12 | karibib
# Processing Record 42 of Set 12 | manga
# Processing Record 43 of Set 12 | la roda
# Processing Record 44 of Set 12 | puerto escondido
# Processing Record 45 of Set 12 | puerto colombia
# Processing Record 46 of Set 12 | paracuru
# Processing Record 47 of Set 12 | peniche
# Processing Record 48 of Set 12 | mecca
# Processing Record 49 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 50 of Set 12 | soconusco
# Processing Record 1 of Set 13 | mana
# Processing Record 2 of Set 13 | asau
# Processing Record 3 of Set 13 | ati
# Processing Record 4 of Set 13 | teguise
# Processing Record 5 of Set 13 | mattoon
# Processing Record 6 of Set 13 | odda
# Processing Record 7 of Set 13 | eureka
# Processing Record 8 of Set 13 | demba
# Processing Record 9 of Set 13 | vargashi
# Processing Record 10 of Set 13 | hirtshals
# Processing Record 11 of Set 13 | moose factory
# Processing Record 12 of Set 13 | dwarka
# Processing Record 13 of Set 13 | musafirkhana
# Processing Record 14 of Set 13 | sheltozero
# Processing Record 15 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 13 | the valley
# Processing Record 17 of Set 13 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 18 of Set 13 | provideniya
# Processing Record 19 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 20 of Set 13 | praia da vitoria
# Processing Record 21 of Set 13 | gravdal
# Processing Record 22 of Set 13 | ginda
# Processing Record 23 of Set 13 | opuwo
# Processing Record 24 of Set 13 | tromso
# Processing Record 25 of Set 13 | jumla
# Processing Record 26 of Set 13 | beyneu
# Processing Record 27 of Set 13 | uvalde
# Processing Record 28 of Set 13 | petatlan
# Processing Record 29 of Set 13 | castelldefels
# Processing Record 30 of Set 13 | muros
# Processing Record 31 of Set 13 | francisco morato
# Processing Record 32 of Set 13 | vicuna
# Processing Record 33 of Set 13 | herat
# Processing Record 34 of Set 13 | simao
# Processing Record 35 of Set 13 | cockburn town
# Processing Record 36 of Set 13 | la ronge
# Processing Record 37 of Set 13 | khani
# Processing Record 38 of Set 13 | iralaya
# Processing Record 39 of Set 13 | amos
# Processing Record 40 of Set 13 | arlit
# Processing Record 41 of Set 13 | bacungan
# Processing Record 42 of Set 13 | presidente medici
# Processing Record 43 of Set 13 | atherton
# Processing Record 44 of Set 13 | wapakoneta
# Processing Record 45 of Set 13 | porto novo
# Processing Record 46 of Set 13 | bhadravati
# Processing Record 47 of Set 13 | olinda
# Processing Record 48 of Set 13 | ola
# Processing Record 49 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 50 of Set 13 | novi sanzhary
# Processing Record 1 of Set 14 | glubokoe
# City not found. Skipping...
# Processing Record 2 of Set 14 | sinnamary
# Processing Record 3 of Set 14 | asyut
# Processing Record 4 of Set 14 | sergeyevka
# Processing Record 5 of Set 14 | lichinga
# Processing Record 6 of Set 14 | hervey bay
# Processing Record 7 of Set 14 | ugoofaaru
# Processing Record 8 of Set 14 | rapar
# Processing Record 9 of Set 14 | hovd
# Processing Record 10 of Set 14 | sahuaripa
# Processing Record 11 of Set 14 | nioro
# Processing Record 12 of Set 14 | aneho
# Processing Record 13 of Set 14 | agadez
# Processing Record 14 of Set 14 | henties bay
# Processing Record 15 of Set 14 | kieta
# Processing Record 16 of Set 14 | jodhpur
# Processing Record 17 of Set 14 | vyazemskiy
# Processing Record 18 of Set 14 | ndjole
# Processing Record 19 of Set 14 | annonay
# Processing Record 20 of Set 14 | marzuq
# Processing Record 21 of Set 14 | vestmannaeyjar
# Processing Record 22 of Set 14 | homer
# Processing Record 23 of Set 14 | svetlaya
# Processing Record 24 of Set 14 | oros
# Processing Record 25 of Set 14 | wrzesnia
# Processing Record 26 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 14 | oriximina
# Processing Record 28 of Set 14 | devils lake
# Processing Record 29 of Set 14 | lixourion
# Processing Record 30 of Set 14 | lusambo
# Processing Record 31 of Set 14 | tokur
# Processing Record 32 of Set 14 | bend
# Processing Record 33 of Set 14 | baker city
# Processing Record 34 of Set 14 | katangli
# Processing Record 35 of Set 14 | gebre guracha
# Processing Record 36 of Set 14 | ilinskiy
# Processing Record 37 of Set 14 | balclutha
# Processing Record 38 of Set 14 | thohoyandou
# Processing Record 39 of Set 14 | shihezi
# Processing Record 40 of Set 14 | shache
# Processing Record 41 of Set 14 | oyama
# Processing Record 42 of Set 14 | meulaboh
# Processing Record 43 of Set 14 | lieksa
# Processing Record 44 of Set 14 | alappuzha
# Processing Record 45 of Set 14 | neiafu
# Processing Record 46 of Set 14 | lindon
# Processing Record 47 of Set 14 | iwanai
# Processing Record 48 of Set 14 | prabumulih
# Processing Record 49 of Set 14 | sabha
# Processing Record 50 of Set 14 | deer lake
# Processing Record 1 of Set 15 | leonidovo
# Processing Record 2 of Set 15 | manjeshwar
# Processing Record 3 of Set 15 | key west
# Processing Record 4 of Set 15 | arcachon
# Processing Record 5 of Set 15 | coffs harbour
# Processing Record 6 of Set 15 | renigunta
# Processing Record 7 of Set 15 | englewood
# Processing Record 8 of Set 15 | pasni
# Processing Record 9 of Set 15 | semirom
# Processing Record 10 of Set 15 | kottagudem
# Processing Record 11 of Set 15 | bondo
# Processing Record 12 of Set 15 | arauca
# Processing Record 13 of Set 15 | robstown
# Processing Record 14 of Set 15 | svetlogorsk
# Processing Record 15 of Set 15 | abashiri
# Processing Record 16 of Set 15 | saposoa
# Processing Record 17 of Set 15 | bogorodskoye
# Processing Record 18 of Set 15 | arecibo
# Processing Record 19 of Set 15 | allahganj
# Processing Record 20 of Set 15 | ampanihy
# Processing Record 21 of Set 15 | tall kayf
# Processing Record 22 of Set 15 | yerbogachen
# Processing Record 23 of Set 15 | grimstad
# Processing Record 24 of Set 15 | jishou
# Processing Record 25 of Set 15 | sao joao da barra
# Processing Record 26 of Set 15 | pangody
# Processing Record 27 of Set 15 | hobyo
# Processing Record 28 of Set 15 | san quintin
# Processing Record 29 of Set 15 | valparaiso
# Processing Record 30 of Set 15 | huarmey
# Processing Record 31 of Set 15 | jiangkou
# Processing Record 32 of Set 15 | manaus
# Processing Record 33 of Set 15 | mangan
# Processing Record 34 of Set 15 | conde
# Processing Record 35 of Set 15 | celestun
# Processing Record 36 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 15 | manado
# Processing Record 38 of Set 15 | ocher
# Processing Record 39 of Set 15 | gavle
# Processing Record 40 of Set 15 | myitkyina
# Processing Record 41 of Set 15 | syasstroy
# Processing Record 42 of Set 15 | san lorenzo
# Processing Record 43 of Set 15 | broken hill
# Processing Record 44 of Set 15 | khandbari
# Processing Record 45 of Set 15 | bara
# Processing Record 46 of Set 15 | kudahuvadhoo
# Processing Record 47 of Set 15 | mnogovershinnyy
# Processing Record 48 of Set 15 | nurota
# Processing Record 49 of Set 15 | costa rica
# Processing Record 50 of Set 15 | sambava
# Processing Record 1 of Set 16 | shingu
# Processing Record 2 of Set 16 | miri
# Processing Record 3 of Set 16 | praya
# Processing Record 4 of Set 16 | fort saint james
# Processing Record 5 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 16 | ust-kuyga
# Processing Record 7 of Set 16 | kailua
# Processing Record 8 of Set 16 | roma
# Processing Record 9 of Set 16 | laguna de perlas
# Processing Record 10 of Set 16 | gazni
# City not found. Skipping...
# Processing Record 11 of Set 16 | nerchinskiy zavod
# Processing Record 12 of Set 16 | ishinomaki
# Processing Record 13 of Set 16 | pyapon
# Processing Record 14 of Set 16 | hegang
# Processing Record 15 of Set 16 | mende
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 707

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Luderitz      NA -26.6481   15.1594     70.27        68           0
# 1    Ushuaia      AR -54.8000  -68.3000     48.20        53          20
# 2   Fillmore      US  43.6666  -92.1002     75.20        20           1
# 3     Avarua      CK -21.2078 -159.7750     82.40        78          75
# 4  Saskylakh      RU  71.9167  114.0833    -26.91       100          25
#
#    Wind Speed Current Description
# 0       18.12           clear sky
# 1        3.44          few clouds
# 2       23.02           clear sky
# 3       14.97          light rain
# 4        3.40    scattered clouds

# %%
# Create the output file (CSV).
file_to_ouput = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(file_to_ouput)
